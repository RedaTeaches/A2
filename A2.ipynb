# %% [markdown]
# **Your Name**
#
# ID: 000000000

# %% [markdown]
# Import Important Libraries

# %%
import re
import operator
import os
import urllib.request
import tarfile
from tabulate import tabulate

# %% [markdown]
#  Reads the content of a file and yields each line.

# %%
def read_data(file_path):
    with open(file_path, 'r', errors='ignore') as file:
        for line in file:
            yield line.rstrip()

# %% [markdown]
# Performs word count analysis on a file.

# %%
def perform_word_count(file_path):
    word_count = {}
    for line in read_data(file_path):
        words = line.split()
        for word in words:
            word = re.sub(r'\W+', '', word.lower())
            if word:
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
    return word_count

# %% [markdown]
# Performs word count analysis on files within a folder.

# %%
def map_reduce(folder_path):
    file_word_counts = {}
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and not file_name.endswith('.tar.gz'):
            word_count = perform_word_count(file_path)
            file_word_counts[file_name] = word_count
    return file_word_counts

# %% [markdown]
#  Displays the word count analysis in a tabular format.

# %%
def display_word_count(word_count):
    sorted_word_count = sorted(word_count.items(), key=operator.itemgetter(1), reverse=True)
    table_data = []
    current_row = []
    words_per_row = 3  # Define the number of words per row here
    for word, count in sorted_word_count:
        current_row.append([word, count])
        if len(current_row) == words_per_row:
            table_data.append(current_row)
            current_row = []

    # Add the remaining words if there are any
    if current_row:
        table_data.append(current_row)

    table = tabulate(table_data, tablefmt="grid")
    print(table)
    print("\n")

# %% [markdown]
#  Saves the word count analysis results to text files.

# %%
def save_word_count(file_word_counts, folder_path):
    save_folder_path = os.path.join(folder_path, "word_results")
    os.makedirs(save_folder_path, exist_ok=True)
    for file_name, word_count in file_word_counts.items():
        sorted_word_count = sorted(word_count.items(), key=operator.itemgetter(1), reverse=True)
        save_file_path = os.path.join(save_folder_path, f"{file_name}_results.txt")
        with open(save_file_path, 'w') as file:
            for word, count in sorted_word_count:
                file.write(f"{word}\t{count}\n")

# %% [markdown]
# Downloads a tar file from the given URL and extracts it

# %%
def download_and_extract_tar(url, save_path):
    print("Downloading tar file...")
    urllib.request.urlretrieve(url, save_path)
    print("Extracting tar file...")
    with tarfile.open(save_path, "r:gz") as tar:
        tar.extractall(os.path.dirname(save_path))
    print("Extraction completed.")

# %% [markdown]
# The main function to perform word count analysis on files.

# %%
def main():
    print("Choose an option:")
    print("1. Perform word count analysis on a single file")
    print("2. Perform word count analysis on files within a folder")
    choice = input("Enter your choice (1 or 2): ")

    if choice == "1":
        file_path = input("Enter the path to the file: ")
        if os.path.isfile(file_path):
            word_count = perform_word_count(file_path)
            display_word_count(word_count)
            save_option = input("Do you want to save the word count results? (y/n): ")
            if save_option.lower() == "y":
                folder_path = os.path.dirname(file_path)
                file_word_counts = {os.path.basename(file_path): word_count}
                save_word_count(file_word_counts, folder_path)
                print("Word count results saved successfully.")
        else:
            print("Invalid file path.")
    elif choice == "2":
        folder_path = input("Enter the path to the folder: ")
        if os.path.isdir(folder_path):
            file_word_counts = map_reduce(folder_path)
            for file_name, word_count in file_word_counts.items():
                print("Word count analysis for file:", file_name)
                display_word_count(word_count)
            save_option = input("Do you want to save the word count results? (y/n): ")
            if save_option.lower() == "y":
                save_word_count(file_word_counts, folder_path)
                print("Word count results saved successfully.")
        else:
            print("Invalid folder path.")
    else:
        print("Invalid choice.")

# %% [markdown]
# Executing the program

# %%
if __name__ == "__main__":
    # Download and extract the tar file
    tar_url = "http://qwone.com/~jason/20Newsgroups/20news-bydate.tar.gz"
    tar_save_path = "20news-bydate.tar.gz"
    download_and_extract_tar(tar_url, tar_save_path)

    # Set the folder path for analysis
    folder_path = "20news-bydate"
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# | ['twice', 1]                           | ['much', 1]                       | ['taxes', 1]                                     |
# +----------------------------------------+-----------------------------------+--------------------------------------------------+
# | ['he', 1]                              | ['formerly', 1]                   | ['got', 1]                                       |
# +----------------------------------------+-----------------------------------+--------------------------------------------------+
# | ['wages', 1]                           | ['h', 1]                          | ['l', 1]                                         |
# +----------------------------------------+-----------------------------------+--------------------------------------------------+
# | ['mencken', 1]                         |                                   |                                                  |
# +----------------------------------------+-----------------------------------+--------------------------------------------------+
#
#
# Word count analysis for file: 38509
# +---------------------------+----------------------------+---------------------+
# | ['o', 10]                 | ['are', 4]                 | ['in', 3]           |
# +---------------------------+----------------------------+---------------------+
# | ['the', 3]                | ['of', 3]                  | ['and', 3]          |
# +---------------------------+----------------------------+---------------------+
# | ['comp', 2]               | ['portugal', 2]            | ['lines', 2]        |
# +---------------------------+----------------------------+---------------------+
# | ['3d', 2]                 | ['text', 2]                | ['a', 2]            |
# +---------------------------+----------------------------+---------------------+
# | ['them', 2]               | ['antonio', 2]             | ['from', 1]         |
# +---------------------------+----------------------------+---------------------+
# | ['cgcadbartinescnpt', 1]  | ['graphicscad', 1]         | ['subject', 1]      |
# +---------------------------+----------------------------+---------------------+
# | ['re', 1]                 | ['fonts', 1]               | ['pov', 1]          |
# +---------------------------+----------------------------+---------------------+
# | ['nntppostinghost', 1]    | ['bart', 1]                | ['organization', 1] |
# +---------------------------+----------------------------+---------------------+
# | ['inescporto', 1]         | ['27', 1]                  | ['hi', 1]           |
# +---------------------------+----------------------------+---------------------+
# | ['rtrace', 1]             | ['ray', 1]                 | ['tracer', 1]       |
# +---------------------------+----------------------------+---------------------+
# | ['supports', 1]           | ['as', 1]                  | ['primitive', 1]    |
# +---------------------------+----------------------------+---------------------+
# | ['not', 1]                | ['collections', 1]         | ['spheres', 1]      |
# +---------------------------+----------------------------+---------------------+
# | ['cylinders', 1]          | ['so', 1]                  | ['on', 1]           |
# +---------------------------+----------------------------+---------------------+
# | ['chars', 1]              | ['made', 1]                | ['splines', 1]      |
# +---------------------------+----------------------------+---------------------+
# | ['that', 1]               | ['extruded', 1]            | ['please', 1]       |
# +---------------------------+----------------------------+---------------------+
# | ['have', 1]               | ['look', 1]                | ['at', 1]           |
# +---------------------------+----------------------------+---------------------+
# | ['asterixinescnpt', 1]    | ['1923524617', 1]          | ['directory', 1]    |
# +---------------------------+----------------------------+---------------------+
# | ['pubrtrace', 1]          | ['pubrtracetmp', 1]        | ['there', 1]        |
# +---------------------------+----------------------------+---------------------+
# | ['some', 1]               | ['demo', 1]                | ['images', 1]       |
# +---------------------------+----------------------------+---------------------+
# | ['with', 1]               | ['high', 1]                | ['quality', 1]      |
# +---------------------------+----------------------------+---------------------+
# | ['all', 1]                | ['called', 1]              | ['textjpg', 1]      |
# +---------------------------+----------------------------+---------------------+
# | ['jpeg', 1]               | ['encoded', 1]             | ['see', 1]          |
# +---------------------------+----------------------------+---------------------+
# | ['first', 1]              | ['then', 1]                | ['tell', 1]         |
# +---------------------------+----------------------------+---------------------+
# | ['me', 1]                 | ['what', 1]                | ['you', 1]          |
# +---------------------------+----------------------------+---------------------+
# | ['think', 1]              | ['regards', 1]             | ['i', 1]            |
# +---------------------------+----------------------------+---------------------+
# | ['n', 1]                  | ['e', 1]                   | ['s', 1]            |
# +---------------------------+----------------------------+---------------------+
# | ['c', 1]                  | ['costa', 1]               | ['email', 1]        |
# +---------------------------+----------------------------+---------------------+
# | ['accasterixinescnpt', 1] | ['acostaportoinescnpt', 1] | ['graphics', 1]     |
# +---------------------------+----------------------------+---------------------+
# | ['cad', 1]                | ['decnet', 1]              | ['portoa_costa', 1] |
# +---------------------------+----------------------------+---------------------+
# | ['largo', 1]              | ['mompilher', 1]           | ['22', 1]           |
# +---------------------------+----------------------------+---------------------+
# | ['uucp', 1]               | ['mcvax', 1]               | ['4100', 1]         |
# +---------------------------+----------------------------+---------------------+
# | ['porto', 1]              | ['bell', 1]                | ['35102321006', 1]  |
# +---------------------------+----------------------------+---------------------+
# | ['let', 1]                | ['good', 1]                | ['times', 1]        |
# +---------------------------+----------------------------+---------------------+
# | ['roll', 1]               |                            |                     |
# +---------------------------+----------------------------+---------------------+
#
#
# Word count analysis for file: 38479
# +--------------------+-------------------+---------------------+
# | ['the', 11]        | ['a', 10]         | ['is', 10]          |
# +--------------------+-------------------+---------------------+
# | ['of', 8]          | ['trimming', 5]   | ['mesh', 4]         |
# +--------------------+-------------------+---------------------+
# | ['to', 4]          | ['be', 4]         | ['help', 3]         |
# +--------------------+-------------------+---------------------+
# | ['i', 3]           | ['problem', 3]    | ['this', 3]         |
# +--------------------+-------------------+---------------------+
# | ['any', 3]         | ['have', 2]       | ['can', 2]          |
# +--------------------+-------------------+---------------------+
# | ['in', 2]          | ['domain', 2]     | ['bezier', 2]       |
# +--------------------+-------------------+---------------------+
# | ['into', 2]        | ['2d', 2]         | ['area', 2]         |
# +--------------------+-------------------+---------------------+
# | ['inside', 2]      | ['loop', 2]       | ['curve', 2]        |
# +--------------------+-------------------+---------------------+
# | ['segments', 2]    | ['for', 2]        | ['up', 2]           |
# +--------------------+-------------------+---------------------+
# | ['cells', 2]       | ['it', 2]         | ['from', 1]         |
# +--------------------+-------------------+---------------------+
# | ['animsukyedu', 1] | ['aniruddha', 1]  | ['b', 1]            |
# +--------------------+-------------------+---------------------+
# | ['deglurkar', 1]   | ['subject', 1]    | ['splitting', 1]    |
# +--------------------+-------------------+---------------------+
# | ['region', 1]      | ['along', 1]      | ['organization', 1] |
# +--------------------+-------------------+---------------------+
# | ['university', 1]  | ['kentucky', 1]   | ['dept', 1]         |
# +--------------------+-------------------+---------------------+
# | ['math', 1]        | ['sciences', 1]   | ['lines', 1]        |
# +--------------------+-------------------+---------------------+
# | ['28', 1]          | ['hi', 1]         | ['hope', 1]         |
# +--------------------+-------------------+---------------------+
# | ['some', 1]        | ['gurus', 1]      | ['me', 1]           |
# +--------------------+-------------------+---------------------+
# | ['solve', 1]       | ['background', 1] | ['rectangular', 1]  |
# +--------------------+-------------------+---------------------+
# | ['uv', 1]          | ['ie', 1]         | ['mapping', 1]      |
# +--------------------+-------------------+---------------------+
# | ['3d', 1]          | ['patch', 1]      | ['which', 1]        |
# +--------------------+-------------------+---------------------+
# | ['had', 1]         | ['rendered', 1]   | ['set', 1]          |
# +--------------------+-------------------+---------------------+
# | ['sake', 1]        | ['notation', 1]   | ['made', 1]         |
# +--------------------+-------------------+---------------------+
# | ['my', 1]          | ['has', 1]        | ['split', 1]        |
# +--------------------+-------------------+---------------------+
# | ['individual', 1]  | ['smaller', 1]    | ['bounded', 1]      |
# +--------------------+-------------------+---------------------+
# | ['by', 1]          | ['if', 1]         | ['cell', 1]         |
# +--------------------+-------------------+---------------------+
# | ['wholly', 1]      | ['areathen', 1]   | ['output', 1]       |
# +--------------------+-------------------+---------------------+
# | ['as', 1]          | ['whole', 1]      | ['else', 1]         |
# +--------------------+-------------------+---------------------+
# | ['trivially', 1]   | ['rejected', 1]   | ['does', 1]         |
# +--------------------+-------------------+---------------------+
# | ['body', 1]        | ['know', 1]       | ['how', 1]          |
# +--------------------+-------------------+---------------------+
# | ['thiss', 1]       | ['done', 1]       | ['or', 1]           |
# +--------------------+-------------------+---------------------+
# | ['there', 1]       | ['algo', 1]       | ['somewhere', 1]    |
# +--------------------+-------------------+---------------------+
# | ['doing', 1]       | ['would', 1]      | ['appreciated', 1]  |
# +--------------------+-------------------+---------------------+
# | ['thanks', 1]      | ['ani', 1]        | ['get', 1]          |
# +--------------------+-------------------+---------------------+
# | ['irritated', 1]   | ['human', 1]      | ['stay', 1]         |
# +--------------------+-------------------+---------------------+
# | ['cool', 1]        | ['divine', 1]     |                     |
# +--------------------+-------------------+---------------------+
#
#
# Word count analysis for file: 38326
# +------------------------+-----------------------------------+-----------------------------+
# | ['this', 4]            | ['valo', 3]                       | ['roman', 3]                |
# +------------------------+-----------------------------------+-----------------------------+
# | ['is', 3]              | ['if', 3]                         | ['to', 3]                   |
# +------------------------+-----------------------------------+-----------------------------+
# | ['or', 3]              | ['from', 2]                       | ['valocvtstucvtstubacs', 2] |
# +------------------------+-----------------------------------+-----------------------------+
# | ['recognition', 2]     | ['software', 2]                   | ['slovak', 2]               |
# +------------------------+-----------------------------------+-----------------------------+
# | ['technical', 2]       | ['university', 2]                 | ['bratislava', 2]           |
# +------------------------+-----------------------------------+-----------------------------+
# | ['slovakia', 2]        | ['b', 2]                          | ['time', 2]                 |
# +------------------------+-----------------------------------+-----------------------------+
# | ['there', 2]           | ['any', 2]                        | ['free', 2]                 |
# +------------------------+-----------------------------------+-----------------------------+
# | ['i', 2]               | ['and', 2]                        | ['anything', 2]             |
# +------------------------+-----------------------------------+-----------------------------+
# | ['the', 2]             | ['im', 2]                         | ['me', 2]                   |
# +------------------------+-----------------------------------+-----------------------------+
# | ['you', 2]             | ['for', 2]                        | ['file', 2]                 |
# +------------------------+-----------------------------------+-----------------------------+
# | ['ocr104zip', 2]       | ['subject', 1]                    | ['re', 1]                   |
# +------------------------+-----------------------------------+-----------------------------+
# | ['text', 1]            | ['availability', 1]               | ['organization', 1]         |
# +------------------------+-----------------------------------+-----------------------------+
# | ['lines', 1]           | ['23', 1]                         | ['nntppostinghost', 1]      |
# +------------------------+-----------------------------------+-----------------------------+
# | ['sk2eueunetsk', 1]    | ['replyto', 1]                    | ['in', 1]                   |
# +------------------------+-----------------------------------+-----------------------------+
# | ['article', 1]         | ['c4ihqm7v3mentorccpurdueedu', 1] | ['abnovaccpurdueedu', 1]    |
# +------------------------+-----------------------------------+-----------------------------+
# | ['allen', 1]           | ['writes', 1]                     | ['one', 1]                  |
# +------------------------+-----------------------------------+-----------------------------+
# | ['more', 1]            | ['ocr', 1]                        | ['out', 1]                  |
# +------------------------+-----------------------------------+-----------------------------+
# | ['ask', 1]             | ['question', 1]                   | ['periodically', 1]         |
# +------------------------+-----------------------------------+-----------------------------+
# | ['havent', 1]          | ['found', 1]                      | ['last', 1]                 |
# +------------------------+-----------------------------------+-----------------------------+
# | ['dont', 1]            | ['find', 1]                       | ['going', 1]                |
# +------------------------+-----------------------------------+-----------------------------+
# | ['write', 1]           | ['some', 1]                       | ['myself', 1]               |
# +------------------------+-----------------------------------+-----------------------------+
# | ['post', 1]            | ['here', 1]                       | ['email', 1]                |
# +------------------------+-----------------------------------+-----------------------------+
# | ['have', 1]            | ['leads', 1]                      | ['suggestions', 1]          |
# +------------------------+-----------------------------------+-----------------------------+
# | ['else', 1]            | ['just', 1]                       | ['sit', 1]                  |
# +------------------------+-----------------------------------+-----------------------------+
# | ['back', 1]            | ['wait', 1]                       | ['ab', 1]                   |
# +------------------------+-----------------------------------+-----------------------------+
# | ['not', 1]             | ['sure', 1]                       | ['shareware', 1]            |
# +------------------------+-----------------------------------+-----------------------------+
# | ['but', 1]             | ['can', 1]                        | ['try', 1]                  |
# +------------------------+-----------------------------------+-----------------------------+
# | ['look', 1]            | ['wsmrsimtel20armymil', 1]        | ['directory', 1]            |
# +------------------------+-----------------------------------+-----------------------------+
# | ['pd1msdosdeskpub', 1] | ['simibmlst', 1]                  | ['93310', 1]                |
# +------------------------+-----------------------------------+-----------------------------+
# | ['910424', 1]          | ['optical', 1]                    | ['character', 1]            |
# +------------------------+-----------------------------------+-----------------------------+
# | ['scanners', 1]        | ['hope', 1]                       | ['helps', 1]                |
# +------------------------+-----------------------------------+-----------------------------+
# | ['valocvtstubacs', 1]  |                                   |                             |
# +------------------------+-----------------------------------+-----------------------------+
#
#
# Word count analysis for file: 38467
# +-------------------+-----------------------------+------------------------------+
# | ['have', 3]       | ['a', 3]                    | ['is', 3]                    |
# +-------------------+-----------------------------+------------------------------+
# | ['not', 3]        | ['thinmannetcomcom', 2]     | ['intersections', 2]         |
# +-------------------+-----------------------------+------------------------------+
# | ['for', 2]        | ['marco', 2]                | ['seirio', 2]                |
# +-------------------+-----------------------------+------------------------------+
# | ['problem', 2]    | ['with', 2]                 | ['to', 2]                    |
# +-------------------+-----------------------------+------------------------------+
# | ['and', 2]        | ['from', 1]                 | ['technically', 1]           |
# +-------------------+-----------------------------+------------------------------+
# | ['sweet', 1]      | ['subject', 1]              | ['re', 1]                    |
# +-------------------+-----------------------------+------------------------------+
# | ['surface', 1]    | ['organization', 1]         | ['international', 1]         |
# +-------------------+-----------------------------+------------------------------+
# | ['foundation', 1] | ['internal', 1]             | ['freedom', 1]               |
# +-------------------+-----------------------------+------------------------------+
# | ['lines', 1]      | ['19', 1]                   | ['sp1marselina', 1]          |
# +-------------------+-----------------------------+------------------------------+
# | ['writes', 1]     | ['i', 1]                    | ['between', 1]               |
# +-------------------+-----------------------------+------------------------------+
# | ['two', 1]        | ['surfaces', 1]             | ['does', 1]                  |
# +-------------------+-----------------------------+------------------------------+
# | ['anybody', 1]    | ['easy', 1]                 | ['understand', 1]            |
# +-------------------+-----------------------------+------------------------------+
# | ['algorithm', 1]  | ['that', 1]                 | ['or', 1]                    |
# +-------------------+-----------------------------+------------------------------+
# | ['maybe', 1]      | ['even', 1]                 | ['c', 1]                     |
# +-------------------+-----------------------------+------------------------------+
# | ['source', 1]     | ['in', 1]                   | ['real', 1]                  |
# +-------------------+-----------------------------+------------------------------+
# | ['life', 1]       | ['sp1marsecaligulahiss', 1] | ['you', 1]                   |
# +-------------------+-----------------------------+------------------------------+
# | ['also', 1]       | ['severe', 1]               | ['news', 1]                  |
# +-------------------+-----------------------------+------------------------------+
# | ['headers', 1]    | ['ftp', 1]                  | ['cspurdueedupubvanecek', 1] |
# +-------------------+-----------------------------+------------------------------+
# | ['pull', 1]       | ['proximatarz', 1]          | ['proximapsz', 1]            |
# +-------------------+-----------------------------+------------------------------+
# | ['tres', 1]       | ['spif', 1]                 | ['lance', 1]                 |
# +-------------------+-----------------------------+------------------------------+
# | ['norskog', 1]    | ['data', 1]                 | ['information', 1]           |
# +-------------------+-----------------------------+------------------------------+
# | ['knowledge', 1]  | ['wisdom', 1]               |                              |
# +-------------------+-----------------------------+------------------------------+
#
#
# Word count analysis for file: 38485
# +------------------------+----------------------------------+---------------------------------+
# | ['the', 13]            | ['a', 10]                        | ['and', 8]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['to', 7]              | ['i', 7]                         | ['3d', 6]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['in', 6]              | ['of', 5]                        | ['it', 5]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['graphics', 4]        | ['library', 4]                   | ['mac', 4]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['can', 4]             | ['you', 4]                       | ['that', 4]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['are', 4]             | ['has', 4]                       | ['for', 3]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['writes', 3]          | ['its', 3]                       | ['would', 3]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['be', 3]              | ['think', 3]                     | ['on', 3]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['before', 3]          | ['lot', 3]                       | ['rgc3679bcsteccaboeingcom', 2] |
# +------------------------+----------------------------------+---------------------------------+
# | ['robert', 2]          | ['g', 2]                         | ['carpenter', 2]                |
# +------------------------+----------------------------------+---------------------------------+
# | ['please', 2]          | ['not', 2]                       | ['there', 2]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['out', 2]             | ['functions', 2]                 | ['line', 2]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['few', 2]             | ['he', 2]                        | ['my', 2]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['too', 2]             | ['quickdraw', 2]                 | ['built', 2]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['them', 2]            | ['as', 2]                        | ['is', 2]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['into', 2]            | ['from', 1]                      | ['subject', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['re', 1]              | ['recommend', 1]                 | ['organization', 1]             |
# +------------------------+----------------------------------+---------------------------------+
# | ['boeing', 1]          | ['lines', 1]                     | ['35', 1]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['article', 1]         | ['1qnm6finn8trtamsuntamuedu', 1] | ['brentbtamsuntamuedu', 1]      |
# +------------------------+----------------------------------+---------------------------------+
# | ['brent', 1]           | ['tsacellarorg', 1]              | ['silent', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['assassin', 1]        | ['offer', 1]                     | ['some', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['recommendations', 1] | ['really', 1]                    | ['hard', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['do', 1]              | ['books', 1]                     | ['which', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['explain', 1]         | ['everything', 1]                | ['basic', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['translation', 1]     | ['rotation', 1]                  | ['shading', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['hidden', 1]          | ['removal', 1]                   | ['pretty', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['easy', 1]            | ['wrote', 1]                     | ['program', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['weeks', 1]           | ['witht', 1]                     | ['help', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['book', 1]            | ['happy', 1]                     | ['give', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['source', 1]          | ['wanted', 1]                    | ['avoid', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['reinventing', 1]     | ['wheel', 1]                     | ['yes', 1]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['want', 1]            | ['concentrate', 1]               | ['other', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['development', 1]     | ['issues', 1]                    | ['ive', 1]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['created', 1]         | ['libraries', 1]                 | ['time', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['consuming', 1]       | ['lifes', 1]                     | ['short', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['also', 1]            | ['pascal', 1]                    | ['access', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['expect', 1]          | ['c', 1]                         | ['could', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['well', 1]            | ['if', 1]                        | ['find', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['how', 1]             | ['use', 1]                       | ['an', 1]                       |
# +------------------------+----------------------------------+---------------------------------+
# | ['excellent', 1]       | ['choice', 1]                    | ['since', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['stuff', 1]           | ['so', 1]                        | ['should', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['fast', 1]            | ['just', 1]                      | ['clarify', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['routines', 1]        | ['mentioned', 1]                 | ['various', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['places', 1]          | ['libray', 1]                    | ['rom', 1]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['years', 1]           | ['ago', 1]                       | ['knew', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['anything', 1]        | ['about', 1]                     | ['implementing', 1]             |
# +------------------------+----------------------------------+---------------------------------+
# | ['came', 1]            | ['across', 1]                    | ['demo', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
# | ['apple', 1]           | ['grafsys3d', 1]                 | ['actually', 1]                 |
# +------------------------+----------------------------------+---------------------------------+
# | ['did', 1]             | ['however', 1]                   | ['quite', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['limited', 1]         | ['sense', 1]                     | ['lowlevel', 1]                 |
# +------------------------+----------------------------------+---------------------------------+
# | ['your', 1]            | ['code', 1]                      | ['still', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['plot', 1]            | ['individual', 1]                | ['points', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['draw', 1]            | ['each', 1]                      | ['etc', 1]                      |
# +------------------------+----------------------------------+---------------------------------+
# | ['ad', 1]              | ['nauseum', 1]                   | ['nothing', 1]                  |
# +------------------------+----------------------------------+---------------------------------+
# | ['gl', 1]              | ['example', 1]                   | ['where', 1]                    |
# +------------------------+----------------------------------+---------------------------------+
# | ['handle', 1]          | ['objects', 1]                   | ['thanks', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['clarification', 1]   | ['posting', 1]                   | ['original', 1]                 |
# +------------------------+----------------------------------+---------------------------------+
# | ['request', 1]         | ['had', 1]                       | ['looked', 1]                   |
# +------------------------+----------------------------------+---------------------------------+
# | ['macs', 1]            | ['capabilities', 1]              | ['dismissed', 1]                |
# +------------------------+----------------------------------+---------------------------------+
# | ['low', 1]             | ['grade', 1]                     | ['bobc', 1]                     |
# +------------------------+----------------------------------+---------------------------------+
#
#
# Word count analysis for file: 38368
# +---------------------+---------------------------------+-------------------+
# | ['help', 3]         | ['to', 3]                       | ['in', 3]         |
# +---------------------+---------------------------------+-------------------+
# | ['mode', 3]         | ['end', 3]                      | ['david', 2]      |
# +---------------------+---------------------------------+-------------------+
# | ['need', 2]         | ['program', 2]                  | ['ive', 2]        |
# +---------------------+---------------------------------+-------------------+
# | ['got', 2]          | ['with', 2]                     | ['the', 2]        |
# +---------------------+---------------------------------+-------------------+
# | ['for', 2]          | ['320200256', 2]                | ['and', 2]        |
# +---------------------+---------------------------------+-------------------+
# | ['i', 2]            | ['code', 2]                     | ['procedure', 2]  |
# +---------------------+---------------------------------+-------------------+
# | ['begin', 2]        | ['videomode', 2]                | ['mov', 2]        |
# +---------------------+---------------------------------+-------------------+
# | ['from', 1]         | ['bergerchaoscsbrandeisedu', 1] | ['berger', 1]     |
# +---------------------+---------------------------------+-------------------+
# | ['subject', 1]      | ['some', 1]                     | ['graphics', 1]   |
# +---------------------+---------------------------------+-------------------+
# | ['organization', 1] | ['brandeis', 1]                 | ['university', 1] |
# +---------------------+---------------------------------+-------------------+
# | ['lines', 1]        | ['32', 1]                       | ['im', 1]         |
# +---------------------+---------------------------------+-------------------+
# | ['trying', 1]       | ['my', 1]                       | ['vga', 1]        |
# +---------------------+---------------------------------+-------------------+
# | ['it', 1]           | ['working', 1]                  | ['pascal', 1]     |
# +---------------------+---------------------------------+-------------------+
# | ['following', 1]    | ['routines', 1]                 | ['13h', 1]        |
# +---------------------+---------------------------------+-------------------+
# | ['a', 1]            | ['vesa', 1]                     | ['compatable', 1] |
# +---------------------+---------------------------------+-------------------+
# | ['trident', 1]      | ['8900c', 1]                    | ['w1meg', 1]      |
# +---------------------+---------------------------------+-------------------+
# | ['1024768', 1]      | ['dont', 1]                     | ['care', 1]       |
# +---------------------+---------------------------------+-------------------+
# | ['how', 1]          | ['many', 1]                     | ['colors', 1]     |
# +---------------------+---------------------------------+-------------------+
# | ['could', 1]        | ['someone', 1]                  | ['take', 1]       |
# +---------------------+---------------------------------+-------------------+
# | ['this', 1]         | ['me', 1]                       | ['write', 1]      |
# +---------------------+---------------------------------+-------------------+
# | ['2', 1]            | ['new', 1]                      | ['procedures', 1] |
# +---------------------+---------------------------------+-------------------+
# | ['replace', 1]      | ['them', 1]                     | ['so', 1]         |
# +---------------------+---------------------------------+-------------------+
# | ['that', 1]         | ['itll', 1]                     | ['work', 1]       |
# +---------------------+---------------------------------+-------------------+
# | ['102476816', 1]    | ['or', 1]                       | ['1024768256', 1] |
# +---------------------+---------------------------------+-------------------+
# | ['thatd', 1]        | ['be', 1]                       | ['great', 1]      |
# +---------------------+---------------------------------+-------------------+
# | ['thanks', 1]       | ['here', 1]                     | ['is', 1]         |
# +---------------------+---------------------------------+-------------------+
# | ['currently', 1]    | ['have', 1]                     | ['graphmode', 1]  |
# +---------------------+---------------------------------+-------------------+
# | ['asm', 1]          | ['ah00', 1]                     | ['al13h', 1]      |
# +---------------------+---------------------------------+-------------------+
# | ['int', 1]          | ['10h', 1]                      | ['plotpoint', 1]  |
# +---------------------+---------------------------------+-------------------+
# | ['x', 1]            | ['y', 1]                        | ['c', 1]          |
# +---------------------+---------------------------------+-------------------+
# | ['integer', 1]      | ['mema000xy320c', 1]            |                   |
# +---------------------+---------------------------------+-------------------+
#
#
# Word count analysis for file: 38383
# +-----------------------+-----------------------------------+---------------------------+
# | ['it', 5]             | ['in', 3]                         | ['is', 3]                 |
# +-----------------------+-----------------------------------+---------------------------+
# | ['i', 3]              | ['bryan', 2]                      | ['not', 2]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['vgalib', 2]         | ['package', 2]                    | ['that', 2]               |
# +-----------------------+-----------------------------------+---------------------------+
# | ['to', 2]             | ['a', 2]                          | ['320x200', 2]            |
# +-----------------------+-----------------------------------+---------------------------+
# | ['very', 2]           | ['thanks', 2]                     | ['from', 1]               |
# +-----------------------+-----------------------------------+---------------------------+
# | ['bryanwrahulnet', 1] | ['woodworth', 1]                  | ['subject', 1]            |
# +-----------------------+-----------------------------------+---------------------------+
# | ['re', 1]             | ['cview', 1]                      | ['answers', 1]            |
# +-----------------------+-----------------------------------+---------------------------+
# | ['organization', 1]   | ['a2i', 1]                        | ['network', 1]            |
# +-----------------------+-----------------------------------+---------------------------+
# | ['lines', 1]          | ['13', 1]                         | ['nntppostinghost', 1]    |
# +-----------------------+-----------------------------------+---------------------------+
# | ['bolero', 1]         | ['1993apr1711322312092imagfr', 1] | ['schaeferimagimagfr', 1] |
# +-----------------------+-----------------------------------+---------------------------+
# | ['arno', 1]           | ['schaefer', 1]                   | ['writes', 1]             |
# +-----------------------+-----------------------------------+---------------------------+
# | ['sorry', 1]          | ['this', 1]                       | ['quite', 1]              |
# +-----------------------+-----------------------------------+---------------------------+
# | ['correct', 1]        | ['remember', 1]                   | ['the', 1]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['comes', 1]          | ['with', 1]                       | ['linuxsls', 1]           |
# +-----------------------+-----------------------------------+---------------------------+
# | ['will', 1]           | ['switch', 1]                     | ['vga', 1]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['320x200x256', 1]    | ['mode', 1]                       | ['without', 1]            |
# +-----------------------+-----------------------------------+---------------------------+
# | ['xwindows', 1]       | ['so', 1]                         | ['at', 1]                 |
# +-----------------------+-----------------------------------+---------------------------+
# | ['least', 1]          | ['possible', 1]                   | ['write', 1]              |
# +-----------------------+-----------------------------------+---------------------------+
# | ['gif', 1]            | ['viewer', 1]                     | ['under', 1]              |
# +-----------------------+-----------------------------------+---------------------------+
# | ['linux', 1]          | ['however', 1]                    | ['dont', 1]               |
# +-----------------------+-----------------------------------+---------------------------+
# | ['think', 1]          | ['there', 1]                      | ['exists', 1]             |
# +-----------------------+-----------------------------------+---------------------------+
# | ['similar', 1]        | ['svga', 1]                       | ['and', 1]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['viewing', 1]        | ['gifs', 1]                       | ['nice', 1]               |
# +-----------------------+-----------------------------------+---------------------------+
# | ['no', 1]             | ['amazing', 1]                    | ['guess', 1]              |
# +-----------------------+-----------------------------------+---------------------------+
# | ['was', 1]            | ['lost', 1]                       | ['all', 1]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['those', 1]          | ['subdirs', 1]                    | ['for', 1]                |
# +-----------------------+-----------------------------------+---------------------------+
# | ['correcting', 1]     | ['me', 1]                         | ['doesnt', 1]             |
# +-----------------------+-----------------------------------+---------------------------+
# | ['sound', 1]          | ['appealing', 1]                  | ['though', 1]             |
# +-----------------------+-----------------------------------+---------------------------+
# | ['only', 1]           | ['im', 1]                         | ['glad', 1]               |
# +-----------------------+-----------------------------------+---------------------------+
# | ['wasnt', 1]          | ['something', 1]                  | ['major', 1]              |
# +-----------------------+-----------------------------------+---------------------------+
# | ['missed', 1]         |                                   |                           |
# +-----------------------+-----------------------------------+---------------------------+
#
#
# Word count analysis for file: 38439
# +------------------------+-----------------------+-------------------+
# | ['speedstar', 3]       | ['stefan', 2]         | ['24', 2]         |
# +------------------------+-----------------------+-------------------+
# | ['i', 2]               | ['to', 2]             | ['from', 1]       |
# +------------------------+-----------------------+-------------------+
# | ['d91hesteknhjse', 1]  | ['hermansson', 1]     | ['subject', 1]    |
# +------------------------+-----------------------+-------------------+
# | ['re', 1]              | ['vesa', 1]           | ['on', 1]         |
# +------------------------+-----------------------+-------------------+
# | ['the', 1]             | ['organization', 1]   | ['hgskolan', 1]   |
# +------------------------+-----------------------+-------------------+
# | ['jnkping', 1]         | ['lines', 1]          | ['8', 1]          |
# +------------------------+-----------------------+-------------------+
# | ['nntppostinghost', 1] | ['pc9_b109ethjse', 1] | ['just', 1]       |
# +------------------------+-----------------------+-------------------+
# | ['posting', 1]         | ['john', 1]           | ['cormack', 1]    |
# +------------------------+-----------------------+-------------------+
# | ['wanted', 1]          | ['tell', 1]           | ['you', 1]        |
# +------------------------+-----------------------+-------------------+
# | ['that', 1]            | ['there', 1]          | ['is', 1]         |
# +------------------------+-----------------------+-------------------+
# | ['a', 1]               | ['slight', 1]         | ['difference', 1] |
# +------------------------+-----------------------+-------------------+
# | ['between', 1]         | ['and', 1]            | ['24x', 1]        |
# +------------------------+-----------------------+-------------------+
#
#
# Word count analysis for file: 38395
# +------------------------------------+----------------------------+------------------------+
# | ['from', 3]                        | ['rayshade', 3]            | ['uw', 3]              |
# +------------------------------------+----------------------------+------------------------+
# | ['on', 3]                          | ['the', 3]                 | ['out', 2]             |
# +------------------------------------+----------------------------+------------------------+
# | ['of', 2]                          | ['im', 2]                  | ['here', 2]            |
# +------------------------------------+----------------------------+------------------------+
# | ['and', 2]                         | ['some', 2]                | ['if', 2]              |
# +------------------------------------+----------------------------+------------------------+
# | ['finemanstein2uwashingtonedu', 1] | ['twixt', 1]               | ['your', 1]            |
# +------------------------------------+----------------------------+------------------------+
# | ['toes', 1]                        | ['subject', 1]             | ['anyone', 1]          |
# +------------------------------------+----------------------------+------------------------+
# | ['know', 1]                        | ['use', 1]                 | ['there', 1]           |
# +------------------------------------+----------------------------+------------------------+
# | ['organization', 1]                | ['university', 1]          | ['washington', 1]      |
# +------------------------------------+----------------------------+------------------------+
# | ['lines', 1]                       | ['12', 1]                  | ['nntppostinghost', 1] |
# +------------------------------------+----------------------------+------------------------+
# | ['stein2uwashingtonedu', 1]        | ['keywords', 1]            | ['using', 1]           |
# +------------------------------------+----------------------------+------------------------+
# | ['computers', 1]                   | ['id', 1]                  | ['like', 1]            |
# +------------------------------------+----------------------------+------------------------+
# | ['input', 1]                       | ['other', 1]               | ['users', 1]           |
# +------------------------------------+----------------------------+------------------------+
# | ['perhaps', 1]                     | ['swap', 1]                | ['ideas', 1]           |
# +------------------------------------+----------------------------+------------------------+
# | ['i', 1]                           | ['could', 1]               | ['post', 1]            |
# ...
# | ['software', 1]    | ['inc', 1]                    | ['lines', 1]                              |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['15', 1]          | ['gchenessexecnuoknoredu', 1] | ['writes', 1]                             |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['in', 1]          | ['article', 1]                | ['c55doh2aiconstellationecnuoknoredu', 1] |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['greetings', 1]   | ['does', 1]                   | ['anybody', 1]                            |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['know', 1]        | ['if', 1]                     | ['possible', 1]                           |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['set', 1]         | ['instead', 1]                | ['of', 1]                                 |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['info', 1]        | ['appreciated', 1]            | ['some', 1]                               |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['bioss', 1]       | ['0x100', 1]                  | ['and', 1]                                |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['should', 1]      | ['be', 1]                     | ['able', 1]                               |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['256', 1]         | ['colors', 1]                 | ['since', 1]                              |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['requires', 1]    | ['256000', 1]                 | ['bytes', 1]                              |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['my', 1]          | ['tsr', 1]                    | ['supports', 1]                           |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['its', 1]         | ['the', 1]                    | ['card', 1]                               |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['can', 1]         | ['due', 1]                    | ['restrictions', 1]                       |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['a', 1]           | ['wdparadise', 1]             | ['am', 1]                                 |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['not', 1]         | ['responsible', 1]            | ['for', 1]                                |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['anything', 1]    | ['do', 1]                     | ['or', 1]                                 |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['say', 1]         | ['im', 1]                     | ['just', 1]                               |
# +--------------------+-------------------------------+-------------------------------------------+
# | ['an', 1]          | ['opinion', 1]                |                                           |
# +--------------------+-------------------------------+-------------------------------------------+
#
#
# Word count analysis for file: 38501
# +--------------------------+------------------+---------------------+
# | ['speedstar', 4]         | ['24x', 4]       | ['on', 3]           |
# +--------------------------+------------------+---------------------+
# | ['routines', 3]          | ['bit', 3]       | ['i', 3]            |
# +--------------------------+------------------+---------------------+
# | ['to', 3]                | ['david', 2]     | ['max', 2]          |
# +--------------------------+------------------+---------------------+
# | ['24bit', 2]             | ['mode', 2]      | ['for', 2]          |
# +--------------------------+------------------+---------------------+
# | ['24', 2]                | ['color', 2]     | ['diamond', 2]      |
# +--------------------------+------------------+---------------------+
# | ['have', 2]              | ['a', 2]         | ['board', 2]        |
# +--------------------------+------------------+---------------------+
# | ['graphics', 2]          | ['the', 2]       | ['from', 1]         |
# +--------------------------+------------------+---------------------+
# | ['maxslinkynyuedu', 1]   | ['subject', 1]   | ['summary', 1]      |
# +--------------------------+------------------+---------------------+
# | ['keywords', 1]          | ['167', 1]       | ['organization', 1] |
# +--------------------------+------------------+---------------------+
# | ['new', 1]               | ['york', 1]      | ['university', 1]   |
# +--------------------------+------------------+---------------------+
# | ['lines', 1]             | ['12', 1]        | ['that', 1]         |
# +--------------------------+------------------+---------------------+
# | ['want', 1]              | ['program', 1]   | ['640x480', 1]      |
# +--------------------------+------------------+---------------------+
# | ['or', 1]                | ['possibly', 1]  | ['800x600', 1]      |
# +--------------------------+------------------+---------------------+
# | ['16', 1]                | ['does', 1]      | ['anybody', 1]      |
# +--------------------------+------------------+---------------------+
# | ['any', 1]               | ['libraries', 1] | ['supporting', 1]   |
# +--------------------------+------------------+---------------------+
# | ['these', 1]             | ['modes', 1]     | ['this', 1]         |
# +--------------------------+------------------+---------------------+
# | ['even', 1]              | ['somes', 1]     | ['simple', 1]       |
# +--------------------------+------------------+---------------------+
# | ['set', 1]               | ['and', 1]       | ['plot', 1]         |
# +--------------------------+------------------+---------------------+
# | ['individual', 1]        | ['pixels', 1]    | ['would', 1]        |
# +--------------------------+------------------+---------------------+
# | ['be', 1]                | ['great', 1]     | ['help', 1]         |
# +--------------------------+------------------+---------------------+
# | ['plan', 1]              | ['use', 1]       | ['with', 1]         |
# +--------------------------+------------------+---------------------+
# | ['djgp', 1]              | ['thanks', 1]    | ['in', 1]           |
# +--------------------------+------------------+---------------------+
# | ['advance', 1]           | ['please', 1]    | ['respond', 1]      |
# +--------------------------+------------------+---------------------+
# | ['also', 1]              | ['via', 1]       | ['email', 1]        |
# +--------------------------+------------------+---------------------+
# | ['maxslinkycsnyuedu', 1] |                  |                     |
# +--------------------------+------------------+---------------------+
#
#
# Word count analysis for file: 38412
# +----------------------+------------------------+------------------------------+
# | ['interpolation', 3] | ['the', 3]             | ['disserenginumichedu', 2]   |
# +----------------------+------------------------+------------------------------+
# | ['disser', 2]        | ['i', 2]               | ['to', 2]                    |
# +----------------------+------------------------+------------------------------+
# | ['with', 2]          | ['im', 2]              | ['any', 2]                   |
# +----------------------+------------------------+------------------------------+
# | ['from', 1]          | ['david', 1]           | ['subject', 1]               |
# +----------------------+------------------------+------------------------------+
# | ['2d', 1]            | ['bitmap', 1]          | ['organization', 1]          |
# +----------------------+------------------------+------------------------------+
# | ['university', 1]    | ['of', 1]              | ['michigan', 1]              |
# +----------------------+------------------------+------------------------------+
# | ['lines', 1]         | ['11', 1]              | ['distribution', 1]          |
# +----------------------+------------------------+------------------------------+
# | ['world', 1]         | ['nntppostinghost', 1] | ['vesuviusenginumichedu', 1] |
# +----------------------+------------------------+------------------------------+
# | ['yesterday', 1]     | ['wrote', 1]           | ['a', 1]                     |
# +----------------------+------------------------+------------------------------+
# | ['program', 1]       | ['do', 1]              | ['bilinear', 1]              |
# +----------------------+------------------------+------------------------------+
# | ['ala', 1]           | ['numerical', 1]       | ['recipes', 1]               |
# +----------------------+------------------------+------------------------------+
# | ['pbmplus', 1]       | ['libraries', 1]       | ['pretty', 1]                |
# +----------------------+------------------------+------------------------------+
# | ['happy', 1]         | ['results', 1]         | ['but', 1]                   |
# +----------------------+------------------------+------------------------------+
# | ['looking', 1]       | ['for', 1]             | ['alreadycoded', 1]          |
# +----------------------+------------------------+------------------------------+
# | ['nonlinear', 1]     | ['schemes', 1]         | ['before', 1]                |
# +----------------------+------------------------+------------------------------+
# | ['go', 1]            | ['ahead', 1]           | ['an', 1]                    |
# +----------------------+------------------------+------------------------------+
# | ['try', 1]           | ['write', 1]           | ['one', 1]                   |
# +----------------------+------------------------+------------------------------+
# | ['pointers', 1]      | ['dave', 1]            | ['umcaen', 1]                |
# +----------------------+------------------------+------------------------------+
# | ['user', 1]          | ['services', 1]        | ['wealth', 1]                |
# +----------------------+------------------------+------------------------------+
# | ['is', 1]            | ['wasted', 1]          | ['229', 1]                   |
# +----------------------+------------------------+------------------------------+
# | ['chrysler', 1]      | ['center', 1]          | ['on', 1]                    |
# +----------------------+------------------------+------------------------------+
# | ['old', 1]           | ['313', 1]             | ['7633067', 1]               |
# +----------------------+------------------------+------------------------------+
# | ['ann', 1]           | ['arbor', 1]           | ['mi', 1]                    |
# +----------------------+------------------------+------------------------------+
# | ['481092092', 1]     |                        |                              |
# +----------------------+------------------------+------------------------------+
#
#
# Word count analysis for file: 38494
# +--------------------+----------------------+-------------------------------+
# | ['the', 7]         | ['is', 6]            | ['to', 5]                     |
# +--------------------+----------------------+-------------------------------+
# | ['a', 5]           | ['video', 3]         | ['rgb', 3]                    |
# +--------------------+----------------------+-------------------------------+
# | ['for', 3]         | ['byte', 3]          | ['v', 3]                      |
# +--------------------+----------------------+-------------------------------+
# | ['u', 3]           | ['and', 3]           | ['from', 2]                   |
# +--------------------+----------------------+-------------------------------+
# | ['mmotion', 2]     | ['yuv', 2]           | ['i', 2]                      |
# +--------------------+----------------------+-------------------------------+
# | ['am', 2]          | ['format', 2]        | ['y', 2]                      |
# +--------------------+----------------------+-------------------------------+
# | ['127127', 2]      | ['info', 2]          | ['un034214wvnvmswvnetedu', 1] |
# +--------------------+----------------------+-------------------------------+
# | ['subject', 1]     | ['card', 1]          | ['organization', 1]           |
# +--------------------+----------------------+-------------------------------+
# | ['west', 1]        | ['virginia', 1]      | ['network', 1]                |
# +--------------------+----------------------+-------------------------------+
# | ['educational', 1] | ['telecomputing', 1] | ['lines', 1]                  |
# +--------------------+----------------------+-------------------------------+
# | ['21', 1]          | ['trying', 1]        | ['convert', 1]                |
# +--------------------+----------------------+-------------------------------+
# | ['an', 1]          | ['ibm', 1]           | ['file', 1]                   |
# +--------------------+----------------------+-------------------------------+
# | ['data', 1]        | ['portion', 1]       | ['0255', 1]                   |
# +--------------------+----------------------+-------------------------------+
# | ['color', 1]       | ['intensity', 1]     | ['does', 1]                   |
# +--------------------+----------------------+-------------------------------+
# | ['anyone', 1]      | ['have', 1]          | ['any', 1]                    |
# +--------------------+----------------------+-------------------------------+
# | ['ideas', 1]       | ['algorhtyms', 1]    | ['or', 1]                     |
# +--------------------+----------------------+-------------------------------+
# | ['programs', 1]    | ['can', 1]           | ['someone', 1]                |
# +--------------------+----------------------+-------------------------------+
# | ['tell', 1]        | ['me', 1]            | ['where', 1]                  |
# +--------------------+----------------------+-------------------------------+
# | ['get', 1]         | ['on', 1]            | ['of', 1]                     |
# +--------------------+----------------------+-------------------------------+
# | ['television', 1]  | ['signal', 1]        | ['if', 1]                     |
# +--------------------+----------------------+-------------------------------+
# | ['you', 1]         | ['need', 1]          | ['more', 1]                   |
# +--------------------+----------------------+-------------------------------+
# | ['reply', 1]       | ['at', 1]            | ['email', 1]                  |
# +--------------------+----------------------+-------------------------------+
# | ['address', 1]     | ['basically', 1]     | ['what', 1]                   |
# +--------------------+----------------------+-------------------------------+
# | ['doing', 1]       | ['converting', 1]    | ['digital', 1]                |
# +--------------------+----------------------+-------------------------------+
# | ['ntsc', 1]        | ['vga', 1]           | ['displaying', 1]             |
# +--------------------+----------------------+-------------------------------+
# | ['captured', 1]    | ['pictures', 1]      | ['thanks', 1]                 |
# +--------------------+----------------------+-------------------------------+
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Do you want to save the word count results? (y/n): y
# Word count results saved successfully.
